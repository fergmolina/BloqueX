# %%
import pandas as pd

# %%
# Cargamos en memoria el csv de contratos. Para mayor detalle del schema acceder a https://ethereum-etl.readthedocs.io/en/latest/schema/
tokens = pd.read_csv('tokens.csv')

# %%
# Filtramos el csv para solo quedarnos con ERC-20 y ERC-721
tokens = tokens[(tokens['symbol'].notna()) & (tokens['name'].notna())]
# Out:
#                                        address      symbol  \
# 0   0xdcb679ac6c72d438e66d39f3fb3364ded7254fc9        wLAC
# 6   0x4eb845fc5eedcf3f1a7925f47372a3a9aa437ade     WDREXtr
# 11  0x1225033ebb3b455a637c60eb3c1feb336f99e48a  UREIAFER01
# 12  0x19d17ac1039d4ed9ce9793e1de28d6eddf17047b       wDrex
# 16  0x4e719e4a41fb9badb354081ecad236adc7959e42   CPRMIL005
#
#                   name  decimals           total_supply  block_number
# 0   Nativo Wrapped LAC      18.0  360200000000000000482           NaN
# 6       RealTokenizado       2.0                      0           NaN
# 11  Fertilizante Ureia       0.0                  60000           NaN
# 12               wDREX      18.0    1000000000000000000           NaN
# 16      Milho em Graos       0.0                  30000           NaN

# %%
tokens
# Out:
#                                        address           symbol  \
# 0   0xdcb679ac6c72d438e66d39f3fb3364ded7254fc9             wLAC
# 6   0x4eb845fc5eedcf3f1a7925f47372a3a9aa437ade          WDREXtr
# 11  0x1225033ebb3b455a637c60eb3c1feb336f99e48a       UREIAFER01
# 12  0x19d17ac1039d4ed9ce9793e1de28d6eddf17047b            wDrex
# 16  0x4e719e4a41fb9badb354081ecad236adc7959e42        CPRMIL005
# 30  0x55fe4a300fadb38f774ccfa596f95a5e39e70b60             TUCU
# 33  0x1cb7b2345fdb20f09f6e9f279c83fdd5c0861872              TUC
# 35  0x5ff9e60e4bdc78dce87975462123aa8b6db70038  Criptodolar UXD
# 40  0x8e613fe158a8bc3630fa5dcfdfddbfb5a993f252  USDT Stablecoin
# 41  0xa4816918564be961180a05cc5ef86e3f874480e2       PoditToken
# 42  0x8ce154a854425c9ca92adff1bada9bcfc55a0980  USDT Stablecoin
# 44  0x9ecb9edc899b40bf8e2a1198ad6ec1fb28e11fef  USDT Stablecoin
# 51  0xb7fe63fcad3f4dc3d49060629529fe4200203839               UD
# 52  0xffc9dd306fa26d6eaab6df434cfc96968ab91348  USDT Stablecoin
# ...
